# %%
import json

# %%
with open(
    "../data/parsed_docs/Ohio_state_university_asset-management-policy.json",
    "r",
    encoding="utf-8"
) as file:

    parsed_doc = json.load(file)

print("File Name:")
print(parsed_doc["file_name"])

print("\nTotal Pages:")
print(len(parsed_doc["pages"]))
# Out:
# File Name:
# Ohio_state_university_asset-management-policy.pdf
#
# Total Pages:
# 9

# %%
print(parsed_doc["pages"][0]["text"][:1000])
# Out:
# The Ohio State University – University Policies policies.osu.edu Page 1 of 9 Asset Management University Policy Applies to: Faculty, staff, graduate associates, student employees, students, and volunteers, excluding those in the Health System. The Health System is covered by a separate policy. Responsible Office Office of Business and Finance POLICY Issued: 07/01/1975 Revised: 01/07/2021 Edited: 12/12/2022 As a large public institution, The Ohio State University is held to a high degree of public scrutiny and accountability for its business practices. The university seeks to promote accountability and ensure the ongoing fiscal integrity of the university through the effective management of university assets. Capital assets must be tracked in accordance with state and federal regulations to ensure that such assets are monitored responsibly and that assets are used in accordance with the university mission, applicable laws, ethical practices, and university policies and requirements. F
# ...

# %%
with open(
    "../data/chunks/Ohio_state_university_asset-management-policy_chunks.json",
    "r",
    encoding="utf-8"
) as file:

    chunks = json.load(file)

print("Total Chunks:")
print(len(chunks))
# Out:
# Total Chunks:
# 12

# %%
chunks[0]
# Out:
# {'chunk_id': 'Ohio_state_university_asset-management-policy.pdf_p1_c1',
#  'file_name': 'Ohio_state_university_asset-management-policy.pdf',
#  'page_number': 1,
# ...

# %%
print("Chunk ID:", chunks[0]["chunk_id"])
print("Token Count:", chunks[0]["token_count"])
# Out:
# Chunk ID: Ohio_state_university_asset-management-policy.pdf_p1_c1
# Token Count: 543

# %%
print(chunks[0]["text"][:1000])
# Out:
# The Ohio State University – University Policies policies.osu.edu Page 1 of 9 Asset Management University Policy Applies to: Faculty, staff, graduate associates, student employees, students, and volunteers, excluding those in the Health System. The Health System is covered by a separate policy. Responsible Office Office of Business and Finance POLICY Issued: 07/01/1975 Revised: 01/07/2021 Edited: 12/12/2022 As a large public institution, The Ohio State University is held to a high degree of public scrutiny and accountability for its business practices. The university seeks to promote accountability and ensure the ongoing fiscal integrity of the university through the effective management of university assets. Capital assets must be tracked in accordance with state and federal regulations to ensure that such assets are monitored responsibly and that assets are used in accordance with the university mission, applicable laws, ethical practices, and university policies and requirements. F
# ...

# %%
print(chunks[0]["text"][:1000])
